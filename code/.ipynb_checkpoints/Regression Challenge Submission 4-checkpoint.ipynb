# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
import sklearn.metrics as metrics
import missingno as msno
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LassoCV

# %% [markdown]
# I will begin by importing the train and test data, adding a column that differentiates between both sets, concatenating the two data sets, cleaning the data, and adding transformations and dummy variables as needed.
#
# I will then split the data into train and test before creating a model

# %% [markdown]
# # Data Import

# %%
# import train data
house_train = pd.read_csv('../datasets/train.csv')
house_train.head(2)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
#
# [2 rows x 81 columns]

# %%
# import test data
house_test = pd.read_csv('../datasets/test.csv')
house_test.head(2)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
#
# [2 rows x 80 columns]

# %%
# add column to differentiate between train (1) and test (0) data sets
house_train['data_type'] = 1
house_test['data_type'] = 0

# %%
# concatenate the data to clean/transform as needed
frames = [house_train, house_test]
df = pd.concat(frames)

# %%
# check that data was concatenated correctly
print(house_train.shape)
print(house_test.shape)
print(df.shape)
print(house_train.shape[0] + house_test.shape[0] == df.shape[0])
# Out:
# (2051, 82)
# (878, 81)
# (2929, 82)
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2929 entries, 0 to 877
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2929 non-null   int64
#  1   PID              2929 non-null   int64
#  2   MS SubClass      2929 non-null   int64
#  3   MS Zoning        2929 non-null   object
#  4   Lot Frontage     2439 non-null   float64
#  5   Lot Area         2929 non-null   int64
#  6   Street           2929 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2929 non-null   object
#  9   Land Contour     2929 non-null   object
#  10  Utilities        2929 non-null   object
#  11  Lot Config       2929 non-null   object
#  12  Land Slope       2929 non-null   object
#  13  Neighborhood     2929 non-null   object
#  14  Condition 1      2929 non-null   object
#  15  Condition 2      2929 non-null   object
#  16  Bldg Type        2929 non-null   object
# ...

# %%
# SalePrice shows as NaN for test data as expected
df.tail(2)
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 876  1672  527425140           20        RL          60.0      9000   Pave
# 877  1939  535327160           20        RL          70.0      8400   Pave
#
#     Alley Lot Shape Land Contour  ... Pool Area Pool QC Fence Misc Feature  \
# 876   NaN       Reg          Lvl  ...         0     NaN  GdWo          NaN
# 877   NaN       Reg          Lvl  ...         0     NaN  GdWo          NaN
#
#     Misc Val Mo Sold Yr Sold Sale Type  SalePrice  data_type
# 876        0       5    2007       WD         NaN          0
# 877        0       3    2007       WD         NaN          0
#
# [2 rows x 82 columns]

# %% [markdown]
# # Cleaning Data and EDA

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Lot Frontage       490
# Alley             2731
# Mas Vnr Type        23
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2916
# Fence             2357
# Misc Feature      2823
# SalePrice          878
# dtype: int64

# %%
# When I plot the missing values for the full data set, train, and test separately, the graphs appear pretty similar. 
# Those null values may need to be zero instead per the data dictionary

# %%
df[df['data_type'] == 1]['SalePrice'].sort_values()
# Out:
# 1628     12789.0
# 183      13100.0
# 1309     34900.0
# 1292     35000.0
# 1518     35311.0
#           ...
# 151     556581.0
# 1796    582933.0
# 1692    584500.0
# 1964    591587.0
# 1671    611657.0
# Name: SalePrice, Length: 2051, dtype: float64

# %%
df[(df['Alley'].isnull()) & (df['data_type'] == 1)]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %%
msno.bar(df)

# %%
# bar plot of missing values for test data set
msno.bar(df[df['data_type'] == 1])

# %%
# bar plot of missing values for test data set
msno.bar(df[df['data_type'] == 0])

# %%
# I am going to fill the null values with zero since for the most case null values mean there is no sqft, garage, etc.
df.fillna(0, inplace = True)
msno.bar(df)

# %%
df[df['data_type'] == 0].shape
# Out:
# (878, 82)

# %%
df[df['data_type'] == 0]['Lot Area'].sum()
# Out:
# 9049575

# %%
# By graphing the features vs sales price, we can see relationships and outliers. 
# There are two houses with a large lot area and not so high price. I am going to delete those

#

# %%
df[df['data_type'] == 0]['Lot Area'].sum()
# Out:
# 9049575

# %%
df[df['data_type'] == 0].shape
# Out:
# (878, 82)

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['TotRms AbvGrd', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice'], y_vars = ['SalePrice']);

# %%
df[df['data_type'] == 1]['Alley'].value_counts()
# Out:
# 0       1911
# Grvl      85
# Pave      55
# Name: Alley, dtype: int64

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['MS Zoning', 'Street', 'Land Contour', 'Lot Shape'], y_vars = ['SalePrice']);
#'Alley' can't be graphed since it has mix of floats and strings.

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Exterior 1st', 'Exterior 2nd', 'Exter Qual', 'Exter Cond'], y_vars = ['SalePrice']);
# 'Mas Vnr Type' can't be graphed

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Foundation'], y_vars = ['SalePrice']);
# 'Bsmt Qual', 'Bsmt Cond' 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', can't be graphed

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = [ 'Heating', 'Heating QC', 'Central Air', 'Electrical'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Kitchen Qual', 'Functional'], y_vars = ['SalePrice']);
#  'Fireplace Qu', 'Garage Type', 'Garage Finish'

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = [ 'Paved Drive'], y_vars = ['SalePrice']);
# 'Garage Qual', 'Garage Cond', 'Pool QC','Fence'

# %%
#sns.pairplot(df[df['data_type'] == 1], x_vars = ['Misc Feature', 'Sale Type'], y_vars = ['SalePrice']);

# %%
#I am going to dummify my string variables
      
df = pd.get_dummies(df, columns = ['Mo Sold', 'Yr Sold', 'MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope',        
               'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
               'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
               'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air',
               'Electrical', 'Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
               'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature', 'Sale Type'])

# %%
df_X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b04912754097> in <module>
# ----> 1 df_X.shape
#
# NameError: name 'df_X' is not defined

# %%
df_X = df[df['data_type'] == 1].copy()
df_X_submit = df[df['data_type'] == 0].copy()
df_y = df[df['data_type'] == 1]['SalePrice'].copy()
df_y_submit = df[df['data_type'] == 0]['SalePrice'].copy()
df_X = df_X.drop(columns = ['data_type', 'SalePrice'])
df_X = df_X.drop(index = [694, 471])
df_y = df_y.drop(index = [694, 471])
df_X_submit = df_X_submit.drop(columns = ['data_type', 'SalePrice'])

# %%
df_X.shape

# %%
df_y.shape

# %%
# I am going to add interactions to my df using PolynomialFeatures
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
df_overfit_train = poly.fit_transform(df_X)
df_overfit_test = poly.fit_transform(df_X_submit)

# %%
# train/test split
X_train, X_test, y_train, y_test = train_test_split(df_overfit_train, df_y, test_size=0.33, random_state = 42)
y_train_log = y_train.map(np.log)
y_test_log = y_test.map(np.log)

# %%
# Standard Scalar, though it's not recommended to do on encoded
sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %%
# Set up a list of Lasso alphas to check.
l_alphas = np.logspace(-2, 3, 50)

# Cross-validate over our list of Lasso alphas.
lasso_cv = LassoCV(alphas = l_alphas)

# Fit model using best ridge alpha!
lasso_cv.fit(Z_train, y_train_log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66cc60de48e6> in <module>
#       1 # Set up a list of Lasso alphas to check.
# ----> 2 l_alphas = np.logspace(-2, 3, 50)
#       3
#       4 # Cross-validate over our list of Lasso alphas.
#       5 lasso_cv = LassoCV(alphas = l_alphas)
#
# NameError: name 'np' is not defined

# %%
print(lasso_cv.score(Z_train, y_train_log))
print(lasso_cv.score(Z_test, y_test_log))
# Out:
# 0.9637562360416745
# 0.8966160091377939

# %%
y_pred_train = lasso_cv.predict(Z_train)
y_pred_test = lasso_cv.predict(Z_test)

# %%
y_pred_train
# Out:
# array([12.1437227 , 12.2410688 , 12.15321096, ..., 12.42526623,
#        12.62956784, 12.32675797])

# %%
y_train_log
# Out:
# 1153    12.132964
# 1644    12.165771
# 1360    12.367341
# 1639    12.936752
# 1092    12.206073
#           ...
# 1726    12.432268
# 1097    11.589887
# 1132    12.429216
# 1296    12.565494
# 862     12.307275
# Name: SalePrice, Length: 1372, dtype: float64

# %%
mse_train = metrics.mean_squared_error(np.exp(y_train_log), np.exp(y_pred_train))
rmse_train = np.sqrt(mse_train)
rmse_train
# Out:
# 15655.822311482963

# %%
mse_test = metrics.mean_squared_error(np.exp(y_test_log), np.exp(y_pred_test))
rmse_test = np.sqrt(mse_test)
rmse_test
# Out:
# 17699.776335108534

# %%
house_test.shape
# Out:
# (878, 81)

# %%
df_X_submit.shape
# Out:
# (878, 331)

# %%
X_final = df_X_submit.fillna(0)
X__final_overfit = poly.fit_transform(X_final)
Z_final = sc.transform(X__final_overfit)

y_pred_submit = lasso_cv.predict(Z_final)

y_pred_submit.shape
# Out:
# (878,)

# %%
Answer = pd.DataFrame(house_test['Id'])
Answer['SalePrice'] = np.exp(y_pred_submit)
Answer.tail()
# Out:
#        Id      SalePrice
# 873  1662  183533.275323
# 874  1234  217383.077082
# 875  1373  132267.768599
# 876  1672  122442.368877
# 877  1939  127510.473118

# %%
Answer.to_csv('../datasets/submit_4.csv', index = False)

# %%
check = pd.read_csv('../datasets/submit_1.csv')
check.shape
# Out:
# (878, 2)

# %%
model = sm.OLS(df_y, df_X).fit()
model.summary()
