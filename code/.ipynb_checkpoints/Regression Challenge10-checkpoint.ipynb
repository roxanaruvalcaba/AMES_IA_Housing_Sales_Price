# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
import sklearn.metrics as metrics
import missingno as msno
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LassoCV

# %% [markdown]
# I will begin by importing the train and test data, adding a column that differentiates between both sets, concatenating the two data sets, cleaning the data, and adding transformations and dummy variables as needed.
#
# I will then split the data into train and test before creating a model

# %% [markdown]
# # Data Import

# %%
# import train data
house_train = pd.read_csv('../datasets/train.csv')
house_train.head(2)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
#
# [2 rows x 81 columns]

# %%
# import test data
house_test = pd.read_csv('../datasets/test.csv')
house_test.head(2)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
#
# [2 rows x 80 columns]

# %%
# add column to differentiate between train (1) and test (0) data sets
house_train['data_type'] = 1
house_test['data_type'] = 0

# %%
# concatenate the data to clean/transform as needed
frames = [house_train, house_test]
df = pd.concat(frames)

# %%
# check that data was concatenated correctly
print(house_train.shape)
print(house_test.shape)
print(df.shape)
print(house_train.shape[0] + house_test.shape[0] == df.shape[0])
# Out:
# (2051, 82)
# (878, 81)
# (2929, 82)
# True

# %%
# check datatypes and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2929 entries, 0 to 877
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2929 non-null   int64
#  1   PID              2929 non-null   int64
#  2   MS SubClass      2929 non-null   int64
#  3   MS Zoning        2929 non-null   object
#  4   Lot Frontage     2439 non-null   float64
#  5   Lot Area         2929 non-null   int64
#  6   Street           2929 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2929 non-null   object
#  9   Land Contour     2929 non-null   object
#  10  Utilities        2929 non-null   object
#  11  Lot Config       2929 non-null   object
#  12  Land Slope       2929 non-null   object
#  13  Neighborhood     2929 non-null   object
#  14  Condition 1      2929 non-null   object
#  15  Condition 2      2929 non-null   object
#  16  Bldg Type        2929 non-null   object
#  17  House Style      2929 non-null   object
#  18  Overall Qual     2929 non-null   int64
#  19  Overall Cond     2929 non-null   int64
#  20  Year Built       2929 non-null   int64
#  21  Year Remod/Add   2929 non-null   int64
#  22  Roof Style       2929 non-null   object
#  23  Roof Matl        2929 non-null   object
#  24  Exterior 1st     2929 non-null   object
#  25  Exterior 2nd     2929 non-null   object
#  26  Mas Vnr Type     2906 non-null   object
#  27  Mas Vnr Area     2906 non-null   float64
#  28  Exter Qual       2929 non-null   object
#  29  Exter Cond       2929 non-null   object
#  30  Foundation       2929 non-null   object
#  31  Bsmt Qual        2849 non-null   object
#  32  Bsmt Cond        2849 non-null   object
#  33  Bsmt Exposure    2846 non-null   object
#  34  BsmtFin Type 1   2849 non-null   object
#  35  BsmtFin SF 1     2928 non-null   float64
#  36  BsmtFin Type 2   2848 non-null   object
#  37  BsmtFin SF 2     2928 non-null   float64
#  38  Bsmt Unf SF      2928 non-null   float64
#  39  Total Bsmt SF    2928 non-null   float64
#  40  Heating          2929 non-null   object
#  41  Heating QC       2929 non-null   object
#  42  Central Air      2929 non-null   object
#  43  Electrical       2928 non-null   object
#  44  1st Flr SF       2929 non-null   int64
#  45  2nd Flr SF       2929 non-null   int64
#  46  Low Qual Fin SF  2929 non-null   int64
#  47  Gr Liv Area      2929 non-null   int64
#  48  Bsmt Full Bath   2927 non-null   float64
#  49  Bsmt Half Bath   2927 non-null   float64
#  50  Full Bath        2929 non-null   int64
#  51  Half Bath        2929 non-null   int64
#  52  Bedroom AbvGr    2929 non-null   int64
#  53  Kitchen AbvGr    2929 non-null   int64
#  54  Kitchen Qual     2929 non-null   object
#  55  TotRms AbvGrd    2929 non-null   int64
#  56  Functional       2929 non-null   object
#  57  Fireplaces       2929 non-null   int64
#  58  Fireplace Qu     1507 non-null   object
#  59  Garage Type      2772 non-null   object
#  60  Garage Yr Blt    2770 non-null   float64
#  61  Garage Finish    2770 non-null   object
#  62  Garage Cars      2928 non-null   float64
#  63  Garage Area      2928 non-null   float64
#  64  Garage Qual      2770 non-null   object
#  65  Garage Cond      2770 non-null   object
#  66  Paved Drive      2929 non-null   object
#  67  Wood Deck SF     2929 non-null   int64
#  68  Open Porch SF    2929 non-null   int64
#  69  Enclosed Porch   2929 non-null   int64
#  70  3Ssn Porch       2929 non-null   int64
#  71  Screen Porch     2929 non-null   int64
#  72  Pool Area        2929 non-null   int64
#  73  Pool QC          13 non-null     object
#  74  Fence            572 non-null    object
#  75  Misc Feature     106 non-null    object
#  76  Misc Val         2929 non-null   int64
#  77  Mo Sold          2929 non-null   int64
#  78  Yr Sold          2929 non-null   int64
#  79  Sale Type        2929 non-null   object
#  80  SalePrice        2051 non-null   float64
#  81  data_type        2929 non-null   int64
# dtypes: float64(12), int64(28), object(42)
# memory usage: 1.9+ MB

# %%
# check summary statistics
df.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2929.000000  2.929000e+03  2929.000000   2439.000000    2929.000000
# mean   1465.255377  7.143984e+08    57.386480     69.199672   10137.697849
# std     846.003265  1.887291e+08    42.645278     23.337677    7861.902406
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.000000  5.284770e+08    20.000000     58.000000    7440.000000
# 50%    1465.000000  5.354532e+08    50.000000     68.000000    9434.000000
# 75%    2198.000000  9.071811e+08    70.000000     80.000000   11553.000000
# max    2930.000000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2929.000000   2929.000000  2929.000000     2929.000000   2906.000000
# mean       6.093547      5.563332  1971.344145     1984.258450    101.669649
# std        1.409420      1.111678    30.243350       20.859235    178.724156
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1965.000000      0.000000
# 50%        6.000000      5.000000  1973.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    164.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        ...  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count  ...    2929.000000     2929.000000  2929.000000   2929.000000
# mean   ...      47.411062       23.019461     2.593377     16.007511
# std    ...      67.168919       64.148601    25.145578     56.096167
# min    ...       0.000000        0.000000     0.000000      0.000000
# 25%    ...       0.000000        0.000000     0.000000      0.000000
# 50%    ...      27.000000        0.000000     0.000000      0.000000
# 75%    ...      70.000000        0.000000     0.000000      0.000000
# max    ...     742.000000     1012.000000   508.000000    576.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice  \
# count  2929.000000   2929.000000  2929.000000  2929.000000    2051.000000
# mean      2.244111     50.652441     6.214749  2007.790714  181469.701609
# std      35.603235    566.440219     2.714055     1.316757   79258.659352
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129825.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  162500.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  611657.000000
#
#          data_type
# count  2929.000000
# mean      0.700239
# std       0.458231
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# # Cleaning Data and EDA

# %%
# plot missing values
msno.bar(df)

# %%
# list missing values
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Lot Frontage       490
# Alley             2731
# Mas Vnr Type        23
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2916
# Fence             2357
# Misc Feature      2823
# SalePrice          878
# dtype: int64

# %% [markdown]
# The null values for most categories seem to mean that the house does not have that feature. I am going to drop the columns with more than 1k null values and fill the other NaN's with zero

# %%
df = df.drop(columns = ['Misc Feature', 'Fence', 'Pool QC', 'Fireplace Qu', 'Alley', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF'])

# %%
# update list missing values
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Lot Frontage      490
# Mas Vnr Type       23
# Mas Vnr Area       23
# Bsmt Qual          80
# Bsmt Cond          80
# Bsmt Exposure      83
# BsmtFin Type 1     80
# BsmtFin SF 1        1
# BsmtFin Type 2     81
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Electrical          1
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Type       157
# Garage Yr Blt     159
# Garage Finish     159
# Garage Cars         1
# Garage Area         1
# Garage Qual       159
# Garage Cond       159
# SalePrice         878
# dtype: int64

# %%
# I'm going to fill in missing data points with zero

# %%
df = df.fillna(0)

# %%
# By graphing the features vs sales price, we can see relationships and outliers. 
# There are two houses with a large lot area and not so high price. I am going to delete those.
# There are also two poins with large living area and large basement sq ft but not so high price. I will also delete those.

# %%
# checking rows with high lot area
df[(df['data_type'] == 1) & (df['Lot Area'] > 100000)]
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 471  2116  906426060           50        RL           0.0    159000   Pave
# 694  2072  905301050           20        RL           0.0    115149   Pave
#
#     Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 471       IR2          Low    AllPub  ...              0          0
# 694       IR2          Low    AllPub  ...              0          0
#
#     Screen Porch Pool Area Misc Val Mo Sold Yr Sold  Sale Type  SalePrice  \
# 471            0         0      500       6    2007        WD    277000.0
# 694            0         0        0       6    2007        WD    302000.0
#
#      data_type
# 471          1
# 694          1
#
# [2 rows x 77 columns]

# %%
# checking rows with large living area
df[(df['data_type'] == 1) & (df['Gr Liv Area'] > 4000)]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#      Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 960        IR3          Bnk    AllPub  ...              0          0
# 1885       IR1          Bnk    AllPub  ...              0          0
#
#      Screen Porch Pool Area Misc Val Mo Sold Yr Sold  Sale Type  SalePrice  \
# 960             0       480        0       1    2008        New   160000.0
# 1885            0         0    17000      10    2007        New   183850.0
#
#       data_type
# 960           1
# 1885          1
#
# [2 rows x 77 columns]

# %%
# checking rows with large basement
df[(df['data_type'] == 1) & (df['BsmtFin SF 1'] > 4000)]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#      Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 960        IR3          Bnk    AllPub  ...              0          0
# 1885       IR1          Bnk    AllPub  ...              0          0
#
#      Screen Porch Pool Area Misc Val Mo Sold Yr Sold  Sale Type  SalePrice  \
# 960             0       480        0       1    2008        New   160000.0
# 1885            0         0    17000      10    2007        New   183850.0
#
#       data_type
# 960           1
# 1885          1
#
# [2 rows x 77 columns]

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Id', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['TotRms AbvGrd', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['MS Zoning', 'Street', 'Land Contour', 'Lot Shape', 'Foundation'], y_vars = ['SalePrice']);
#'Alley' can't be graphed since it has mix of floats and strings.

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = ['Exterior 1st', 'Exterior 2nd', 'Exter Qual', 'Exter Cond', 'Functional'], y_vars = ['SalePrice']);

# %%
sns.pairplot(df[df['data_type'] == 1], x_vars = [ 'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Kitchen Qual', 'Paved Drive'], y_vars = ['SalePrice']);

# %%
#I am going to dummify my string variables
      
df = pd.get_dummies(df, columns = ['Mo Sold', 'Yr Sold', 'MS Zoning', 'Street', 'Lot Shape', 'Land Contour', 
                                   'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 
                                   'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
                                   'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond', 
                                   'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 
                                   'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air', 'Electrical', 
                                   'Kitchen Qual', 'Functional', 'Garage Type', 'Garage Finish', 'Garage Qual',
                                   'Garage Cond', 'Paved Drive', 'Sale Type'])

# %%
df_X.shape
# Out:
# (2051, 306)

# %%
df_X = df[df['data_type'] == 1].copy()
df_X_submit = df[df['data_type'] == 0].copy()
df_y = df[df['data_type'] == 1]['SalePrice'].copy()
df_y_submit = df[df['data_type'] == 0]['SalePrice'].copy()
df_X = df_X.drop(columns = ['data_type', 'SalePrice'])
df_X = df_X.drop(index = [694, 471, 960, 1885])
df_y = df_y.drop(index = [694, 471, 960, 1885])
df_X_submit = df_X_submit.drop(columns = ['data_type', 'SalePrice'])

# %%
# I am going to add interactions to my df using PolynomialFeatures
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
df_overfit_train = poly.fit_transform(df_X)
df_overfit_test = poly.fit_transform(df_X_submit)

# %%
# train/test split
X_train, X_test, y_train, y_test = train_test_split(df_overfit_train, df_y, test_size=0.33, random_state = 42)
y_train_log = y_train.map(np.log)
y_test_log = y_test.map(np.log)

# %%
# Standard Scalar, though it's not recommended to do on encoded
sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %%
# Set up a list of Lasso alphas to check.

l_alphas = [1, 0.1, 0.001, 0.0005]
#l_alphas = np.logspace(-3, 0, 100)

# Cross-validate over our list of Lasso alphas.
lasso_cv = LassoCV(alphas = l_alphas)

# Fit model using best ridge alpha!
lasso_cv.fit(Z_train, y_train_log)
# Out:
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# LassoCV(alphas=[1, 0.1, 0.001, 0.0005], copy_X=True, cv='warn', eps=0.001,
#     fit_intercept=True, max_iter=1000, n_alphas=100, n_jobs=None,
#     normalize=False, positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)

# %%
print(lasso_cv.score(Z_train, y_train_log))
print(lasso_cv.score(Z_test, y_test_log))
# Out:
# 0.9946518017846612
# 0.8537841961594979

# %%
y_pred_train = lasso_cv.predict(Z_train)
y_pred_test = lasso_cv.predict(Z_test)

# %%
mse_train = metrics.mean_squared_error(np.exp(y_train_log), np.exp(y_pred_train))
rmse_train = np.sqrt(mse_train)
rmse_train
# Out:
# 6056.880135280128

# %%
mse_test = metrics.mean_squared_error(np.exp(y_test_log), np.exp(y_pred_test))
rmse_test = np.sqrt(mse_test)
rmse_test
# Out:
# 22311.614746665782

# %%
lasso_cv.alpha_
# Out:
# 0.001

# %%
house_test.shape

# %%
df_X_submit.shape

# %%
X_final = df_X_submit.fillna(0)
X__final_overfit = poly.fit_transform(X_final)
Z_final = sc.transform(X__final_overfit)

y_pred_submit = lasso_cv.predict(Z_final)

y_pred_submit.shape
# Out:
# (878,)

# %%
Answer = pd.DataFrame(house_test['Id'])
Answer['SalePrice'] = np.exp(y_pred_submit)
Answer.tail()
# Out:
#        Id      SalePrice
# 873  1662  188692.960351
# 874  1234  210835.934490
# 875  1373  129357.480752
# 876  1672  123678.351120
# 877  1939  125686.715292

# %%
Answer.to_csv('../datasets/submit_5.csv', index = False)

# %%
check = pd.read_csv('../datasets/submit_1.csv')
check.shape
# Out:
# (878, 2)

# %%
lasso_cv.alpha_
# Out:
# 0.001

# %%
0.005336699231206312

# %%
model = sm.OLS(df_y, df_X).fit()
model.summary()
# Out:
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/RoxanaRuvalcaba/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     99.40
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                        15:26:56   Log-Likelihood:                -23282.
# No. Observations:                2051   AIC:                         4.707e+04
# Df Residuals:                    1800   BIC:                         4.848e+04
# Df Model:                         250
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Id                     -18.1732      9.638     -1.886      0.060     -37.076       0.729
# PID                   1.866e-05   9.91e-06      1.882      0.060   -7.88e-07    3.81e-05
# MS SubClass            -78.0970     62.816     -1.243      0.214    -201.297      45.103
# Lot Frontage            20.1920     19.314      1.045      0.296     -17.688      58.072
# Lot Area                 0.7474      0.119      6.260      0.000       0.513       0.981
# Overall Qual          6577.2910    805.110      8.169      0.000    4998.242    8156.340
# Overall Cond          5373.5867    705.961      7.612      0.000    3988.997    6758.176
# Year Built             279.5301     61.109      4.574      0.000     159.678     399.382
# Year Remod/Add          56.7488     45.387      1.250      0.211     -32.268     145.766
# Mas Vnr Area            18.0228      4.868      3.702      0.000       8.475      27.570
# BsmtFin SF 1            13.7458      2.144      6.410      0.000       9.540      17.952
# BsmtFin SF 2             9.7655      4.449      2.195      0.028       1.039      18.492
# Bsmt Unf SF             -2.2282      2.034     -1.095      0.273      -6.217       1.761
# Total Bsmt SF           21.2832      2.893      7.356      0.000      15.609      26.958
# 1st Flr SF              12.2116      4.196      2.910      0.004       3.982      20.441
# 2nd Flr SF              22.5889      3.791      5.959      0.000      15.155      30.023
# Low Qual Fin SF         -4.1972      8.854     -0.474      0.636     -21.562      13.168
# Gr Liv Area             30.6031      3.818      8.016      0.000      23.115      38.091
# Bsmt Full Bath        3448.1981   1534.772      2.247      0.025     438.077    6458.319
# Bsmt Half Bath       -3429.2544   2272.952     -1.509      0.132   -7887.156    1028.647
# Full Bath             4433.8898   1700.632      2.607      0.009    1098.469    7769.311
# Half Bath             2574.6703   1622.720      1.587      0.113    -607.943    5757.284
# Bedroom AbvGr        -1942.4332   1039.321     -1.869      0.062   -3980.836      95.970
# Kitchen AbvGr        -1.022e+04   4890.296     -2.090      0.037   -1.98e+04    -631.795
# TotRms AbvGrd          235.4285    733.517      0.321      0.748   -1203.206    1674.063
# Fireplaces            3400.5484   1086.842      3.129      0.002    1268.945    5532.152
# Garage Yr Blt            1.3583     44.988      0.030      0.976     -86.876      89.593
# Garage Cars           3932.7361   1853.320      2.122      0.034     297.852    7567.621
# Garage Area             14.0013      6.481      2.160      0.031       1.291      26.712
# Wood Deck SF            11.5091      4.646      2.477      0.013       2.398      20.621
# Open Porch SF           -3.2854      9.029     -0.364      0.716     -20.993      14.423
# Enclosed Porch          11.1153     10.026      1.109      0.268      -8.549      30.780
# 3Ssn Porch               6.6444     20.805      0.319      0.749     -34.159      47.448
# Screen Porch            59.7172      9.665      6.179      0.000      40.762      78.673
# Pool Area               18.2096     15.173      1.200      0.230     -11.549      47.968
# Misc Val               -12.9364      0.989    -13.084      0.000     -14.876     -10.997
# Mo Sold_1            -5486.3253   2928.034     -1.874      0.061   -1.12e+04     256.378
# Mo Sold_2             -1.08e+04   2618.777     -4.123      0.000   -1.59e+04   -5660.136
# Mo Sold_3            -8786.3164   2346.318     -3.745      0.000   -1.34e+04   -4184.523
# Mo Sold_4            -9175.1050   2279.203     -4.026      0.000   -1.36e+04   -4704.944
# Mo Sold_5            -4944.8574   2111.625     -2.342      0.019   -9086.352    -803.363
# Mo Sold_6            -8660.0124   2051.737     -4.221      0.000   -1.27e+04   -4635.975
# Mo Sold_7            -5393.3947   2079.644     -2.593      0.010   -9472.165   -1314.625
# Mo Sold_8            -9542.9356   2329.644     -4.096      0.000   -1.41e+04   -4973.845
# Mo Sold_9            -7777.0063   2604.481     -2.986      0.003   -1.29e+04   -2668.882
# Mo Sold_10           -1.301e+04   2575.848     -5.051      0.000   -1.81e+04   -7957.860
# Mo Sold_11           -9847.0407   2702.148     -3.644      0.000   -1.51e+04   -4547.365
# Mo Sold_12           -8186.5544   3033.462     -2.699      0.007   -1.41e+04   -2237.077
# Yr Sold_2006          4229.6580   1.33e+04      0.317      0.751    -2.2e+04    3.04e+04
# Yr Sold_2007         -1.045e+04   7455.254     -1.402      0.161   -2.51e+04    4171.198
# Yr Sold_2008         -2.113e+04   3836.139     -5.508      0.000   -2.87e+04   -1.36e+04
# Yr Sold_2009         -3.348e+04   7093.289     -4.720      0.000   -4.74e+04   -1.96e+04
# Yr Sold_2010         -4.077e+04   1.16e+04     -3.522      0.000   -6.35e+04   -1.81e+04
# MS Zoning_A (agr)    -4.492e+04    2.8e+04     -1.606      0.108   -9.98e+04    9940.396
# MS Zoning_C (all)    -2.164e+04   8689.944     -2.491      0.013   -3.87e+04   -4598.924
# MS Zoning_FV         -2286.2513   7569.339     -0.302      0.763   -1.71e+04    1.26e+04
# MS Zoning_I (all)    -2.019e+04   1.22e+04     -1.651      0.099   -4.42e+04    3799.892
# MS Zoning_RH          3250.7772   8608.362      0.378      0.706   -1.36e+04    2.01e+04
# MS Zoning_RL         -4615.8494   6248.950     -0.739      0.460   -1.69e+04    7640.108
# MS Zoning_RM          -1.12e+04   6626.429     -1.690      0.091   -2.42e+04    1797.708
# Street_Grvl          -5.493e+04   1.06e+04     -5.159      0.000   -7.58e+04    -3.4e+04
# Street_Pave          -4.667e+04   1.07e+04     -4.363      0.000   -6.77e+04   -2.57e+04
# Lot Shape_IR1        -2.467e+04   5085.420     -4.850      0.000   -3.46e+04   -1.47e+04
# Lot Shape_IR2        -2.235e+04   5697.616     -3.923      0.000   -3.35e+04   -1.12e+04
# Lot Shape_IR3        -3.051e+04   7990.620     -3.818      0.000   -4.62e+04   -1.48e+04
# Lot Shape_Reg        -2.408e+04   5111.814     -4.711      0.000   -3.41e+04   -1.41e+04
# Land Contour_Bnk      -2.89e+04   5190.895     -5.568      0.000   -3.91e+04   -1.87e+04
# Land Contour_HLS     -1.647e+04   5415.835     -3.042      0.002   -2.71e+04   -5851.207
# Land Contour_Low     -3.162e+04   5828.222     -5.425      0.000    -4.3e+04   -2.02e+04
# Land Contour_Lvl     -2.461e+04   4986.024     -4.936      0.000   -3.44e+04   -1.48e+04
# Utilities_AllPub     -2.604e+04   1.31e+04     -1.981      0.048   -5.18e+04    -257.151
# Utilities_NoSeWa     -5.538e+04   1.68e+04     -3.294      0.001   -8.83e+04   -2.24e+04
# Utilities_NoSewr     -2.019e+04   1.22e+04     -1.651      0.099   -4.42e+04    3799.892
# Lot Config_Corner    -1.809e+04   4212.764     -4.295      0.000   -2.64e+04   -9830.959
# Lot Config_CulDSac   -1.272e+04   4555.087     -2.792      0.005   -2.17e+04   -3783.880
# Lot Config_FR2       -2.315e+04   4753.632     -4.869      0.000   -3.25e+04   -1.38e+04
# Lot Config_FR3       -2.942e+04   7692.589     -3.824      0.000   -4.45e+04   -1.43e+04
# Lot Config_Inside    -1.823e+04   4162.763     -4.379      0.000   -2.64e+04   -1.01e+04
# Land Slope_Gtl       -2.906e+04   7206.455     -4.032      0.000   -4.32e+04   -1.49e+04
# Land Slope_Mod       -2.642e+04   7237.761     -3.650      0.000   -4.06e+04   -1.22e+04
# Land Slope_Sev       -4.613e+04   8549.641     -5.395      0.000   -6.29e+04   -2.94e+04
# Neighborhood_Blmngtn -1681.6023   6072.946     -0.277      0.782   -1.36e+04    1.02e+04
# Neighborhood_Blueste  -489.7964   9799.932     -0.050      0.960   -1.97e+04    1.87e+04
# Neighborhood_BrDale   4304.9359   7428.479      0.580      0.562   -1.03e+04    1.89e+04
# Neighborhood_BrkSide -1.297e+04   4088.152     -3.173      0.002    -2.1e+04   -4955.087
# Neighborhood_ClearCr -1.594e+04   5671.852     -2.810      0.005   -2.71e+04   -4813.589
# Neighborhood_CollgCr -1.628e+04   3568.772     -4.563      0.000   -2.33e+04   -9284.435
# Neighborhood_Crawfor  -402.8762   4026.763     -0.100      0.920   -8300.497    7494.745
# Neighborhood_Edwards -2.504e+04   3387.503     -7.393      0.000   -3.17e+04   -1.84e+04
# Neighborhood_Gilbert -1.932e+04   3899.879     -4.953      0.000    -2.7e+04   -1.17e+04
# Neighborhood_Greens   1525.6619   1.35e+04      0.113      0.910    -2.5e+04     2.8e+04
# Neighborhood_GrnHill  1.073e+05   1.64e+04      6.538      0.000    7.51e+04     1.4e+05
# Neighborhood_IDOTRR  -1.332e+04   5187.715     -2.567      0.010   -2.35e+04   -3142.952
# Neighborhood_Landmrk -1.418e+04    2.3e+04     -0.618      0.537   -5.92e+04    3.08e+04
# Neighborhood_MeadowV -2271.4246   6883.081     -0.330      0.741   -1.58e+04    1.12e+04
# Neighborhood_Mitchel -1.577e+04   4166.207     -3.785      0.000   -2.39e+04   -7598.008
# Neighborhood_NAmes   -1.771e+04   2952.643     -5.998      0.000   -2.35e+04   -1.19e+04
# Neighborhood_NPkVill   -23.1506   1.32e+04     -0.002      0.999   -2.58e+04    2.58e+04
# Neighborhood_NWAmes  -2.122e+04   3795.928     -5.591      0.000   -2.87e+04   -1.38e+04
# Neighborhood_NoRidge  1.592e+04   4619.193      3.447      0.001    6860.860     2.5e+04
# Neighborhood_NridgHt  1.405e+04   3973.813      3.535      0.000    6254.751    2.18e+04
# Neighborhood_OldTown -2.026e+04   3887.805     -5.212      0.000   -2.79e+04   -1.26e+04
# Neighborhood_SWISU   -2.049e+04   5266.490     -3.891      0.000   -3.08e+04   -1.02e+04
# Neighborhood_Sawyer    -1.8e+04   3257.680     -5.525      0.000   -2.44e+04   -1.16e+04
# Neighborhood_SawyerW -1.688e+04   3298.932     -5.117      0.000   -2.34e+04   -1.04e+04
# Neighborhood_Somerst   419.9859   5291.756      0.079      0.937   -9958.645    1.08e+04
# Neighborhood_StoneBr  2.918e+04   5180.520      5.632      0.000     1.9e+04    3.93e+04
# Neighborhood_Timber  -1.354e+04   4848.161     -2.792      0.005    -2.3e+04   -4027.262
# Neighborhood_Veenker -8544.2600   6435.947     -1.328      0.184   -2.12e+04    4078.452
# Condition 1_Artery   -1.759e+04   4088.216     -4.301      0.000   -2.56e+04   -9567.070
# Condition 1_Feedr    -1.053e+04   3729.481     -2.824      0.005   -1.78e+04   -3219.220
# Condition 1_Norm     -5317.9649   3182.256     -1.671      0.095   -1.16e+04     923.339
# Condition 1_PosA      1021.6236   7278.518      0.140      0.888   -1.33e+04    1.53e+04
# Condition 1_PosN      2730.7296   5252.434      0.520      0.603   -7570.779     1.3e+04
# Condition 1_RRAe     -1.976e+04   5799.545     -3.408      0.001   -3.11e+04   -8388.882
# Condition 1_RRAn     -1.183e+04   4958.745     -2.386      0.017   -2.16e+04   -2107.995
# Condition 1_RRNe     -2.102e+04   1.28e+04     -1.643      0.100   -4.61e+04    4067.172
# Condition 1_RRNn      -1.93e+04   9220.273     -2.094      0.036   -3.74e+04   -1221.015
# Condition 2_Artery   -3.017e+04   1.16e+04     -2.612      0.009   -5.28e+04   -7516.977
# Condition 2_Feedr     -2.25e+04   9398.368     -2.394      0.017   -4.09e+04   -4065.056
# Condition 2_Norm     -2.303e+04   6622.488     -3.478      0.001    -3.6e+04      -1e+04
# Condition 2_PosA     -4970.8271   1.44e+04     -0.344      0.731   -3.33e+04    2.34e+04
# Condition 2_PosN     -4.019e+04   1.39e+04     -2.894      0.004   -6.74e+04    -1.3e+04
# Condition 2_RRAe      7.114e+04   2.76e+04      2.574      0.010    1.69e+04    1.25e+05
# Condition 2_RRAn     -2.801e+04   2.11e+04     -1.330      0.184   -6.93e+04    1.33e+04
# Condition 2_RRNn     -2.387e+04   1.58e+04     -1.512      0.131   -5.48e+04    7090.720
# Bldg Type_1Fam       -1.099e+04   5839.173     -1.883      0.060   -2.24e+04     459.094
# Bldg Type_2fmCon     -9276.0931   6694.409     -1.386      0.166   -2.24e+04    3853.536
# Bldg Type_Duplex     -2.036e+04   5948.814     -3.423      0.001    -3.2e+04   -8693.039
# Bldg Type_Twnhs      -3.321e+04   5584.576     -5.948      0.000   -4.42e+04   -2.23e+04
# Bldg Type_TwnhsE     -2.776e+04   4860.776     -5.711      0.000   -3.73e+04   -1.82e+04
# House Style_1.5Fin   -1.291e+04   3327.712     -3.880      0.000   -1.94e+04   -6385.328
# House Style_1.5Unf   -8385.1634   7045.347     -1.190      0.234   -2.22e+04    5432.754
# House Style_1Story   -9606.8991   4314.285     -2.227      0.026   -1.81e+04   -1145.367
# House Style_2.5Fin   -3.224e+04   1.07e+04     -3.007      0.003   -5.33e+04   -1.12e+04
# House Style_2.5Unf   -4377.5363   6748.724     -0.649      0.517   -1.76e+04    8858.619
# House Style_2Story    -1.49e+04   3542.891     -4.205      0.000   -2.18e+04   -7949.789
# House Style_SFoyer   -7640.5569   5116.330     -1.493      0.136   -1.77e+04    2394.013
# House Style_SLvl     -1.154e+04   4450.249     -2.594      0.010   -2.03e+04   -2814.125
# Roof Style_Flat      -2.834e+04   1.09e+04     -2.603      0.009   -4.97e+04   -6984.256
# Roof Style_Gable     -9805.7912   5272.932     -1.860      0.063   -2.01e+04     535.919
# Roof Style_Gambrel   -1.359e+04   7688.498     -1.767      0.077   -2.87e+04    1491.066
# Roof Style_Hip       -7919.4643   5350.255     -1.480      0.139   -1.84e+04    2573.898
# Roof Style_Mansard   -3.856e+04   9701.056     -3.974      0.000   -5.76e+04   -1.95e+04
# Roof Style_Shed      -3395.9009   1.62e+04     -0.210      0.834   -3.51e+04    2.83e+04
# Roof Matl_ClyTile    -5.254e+05   2.63e+04    -19.990      0.000   -5.77e+05   -4.74e+05
# Roof Matl_CompShg     6.369e+04   8462.600      7.527      0.000    4.71e+04    8.03e+04
# Roof Matl_Membran     1.173e+05   2.36e+04      4.972      0.000    7.11e+04    1.64e+05
# Roof Matl_Metal      -4.043e-10   6.43e-11     -6.291      0.000    -5.3e-10   -2.78e-10
# Roof Matl_Roll       -3.939e-10   4.49e-11     -8.768      0.000   -4.82e-10   -3.06e-10
# Roof Matl_Tar&Grv     8.096e+04   1.06e+04      7.620      0.000    6.01e+04    1.02e+05
# Roof Matl_WdShake     7.414e+04   1.42e+04      5.214      0.000    4.63e+04    1.02e+05
# Roof Matl_WdShngl     8.767e+04   1.32e+04      6.666      0.000    6.19e+04    1.13e+05
# Exterior 1st_AsbShng   600.9139   8363.675      0.072      0.943   -1.58e+04     1.7e+04
# Exterior 1st_AsphShn -2.816e+04    2.8e+04     -1.004      0.315   -8.31e+04    2.68e+04
# Exterior 1st_BrkComm  -3.49e+04   1.94e+04     -1.798      0.072    -7.3e+04    3170.971
# Exterior 1st_BrkFace  1.389e+04   5803.559      2.394      0.017    2509.007    2.53e+04
# Exterior 1st_CBlock   2.075e+04   2.77e+04      0.750      0.454   -3.35e+04     7.5e+04
# Exterior 1st_CemntBd  4492.5285    1.7e+04      0.264      0.791   -2.88e+04    3.78e+04
# Exterior 1st_HdBoard -8710.0702   5359.613     -1.625      0.104   -1.92e+04    1801.647
# Exterior 1st_ImStucc  -1.75e+04   2.25e+04     -0.779      0.436   -6.16e+04    2.65e+04
# Exterior 1st_MetalSd -4871.6370   7357.976     -0.662      0.508   -1.93e+04    9559.434
# Exterior 1st_Plywood -6690.7919   5337.288     -1.254      0.210   -1.72e+04    3777.140
# Exterior 1st_PreCast -6.311e-11   4.13e-11     -1.529      0.126   -1.44e-10    1.78e-11
# Exterior 1st_Stone   -1.585e+04   1.84e+04     -0.863      0.388   -5.19e+04    2.02e+04
# Exterior 1st_Stucco  -1457.1663   7356.555     -0.198      0.843   -1.59e+04     1.3e+04
# Exterior 1st_VinylSd -1.107e+04   6702.630     -1.651      0.099   -2.42e+04    2079.285
# Exterior 1st_Wd Sdng -7440.4477   5156.150     -1.443      0.149   -1.76e+04    2672.220
# Exterior 1st_WdShing -4694.5933   6083.725     -0.772      0.440   -1.66e+04    7237.311
# Exterior 2nd_AsbShng -1.156e+04   8233.773     -1.404      0.161   -2.77e+04    4590.918
# Exterior 2nd_AsphShn   2.02e+04   1.67e+04      1.209      0.227   -1.26e+04     5.3e+04
# Exterior 2nd_Brk Cmn   -95.9003   1.42e+04     -0.007      0.995    -2.8e+04    2.78e+04
# Exterior 2nd_BrkFace -1.369e+04   6143.306     -2.228      0.026   -2.57e+04   -1640.930
# Exterior 2nd_CBlock  -2.325e+04   2.23e+04     -1.043      0.297    -6.7e+04    2.05e+04
# Exterior 2nd_CmentBd -1.538e+04   1.65e+04     -0.932      0.351   -4.77e+04     1.7e+04
# Exterior 2nd_HdBoard -4694.9136   4504.921     -1.042      0.297   -1.35e+04    4140.511
# Exterior 2nd_ImStucc -1.052e+04   7767.654     -1.354      0.176   -2.58e+04    4714.381
# Exterior 2nd_MetalSd -3421.1122   6689.692     -0.511      0.609   -1.65e+04    9699.266
# Exterior 2nd_Other   -3.939e-11   2.27e-11     -1.732      0.083    -8.4e-11    5.21e-12
# Exterior 2nd_Plywood -6088.7474   4211.003     -1.446      0.148   -1.43e+04    2170.221
# Exterior 2nd_PreCast  1.399e-10   2.51e-11      5.570      0.000    9.07e-11    1.89e-10
# Exterior 2nd_Stone   -2.006e+04    1.1e+04     -1.828      0.068   -4.16e+04    1463.600
# Exterior 2nd_Stucco  -7409.0859   6530.584     -1.135      0.257   -2.02e+04    5399.237
# Exterior 2nd_VinylSd  2273.6623   6099.891      0.373      0.709   -9689.949    1.42e+04
# Exterior 2nd_Wd Sdng -2861.0392   4319.490     -0.662      0.508   -1.13e+04    5610.702
# Exterior 2nd_Wd Shng -5052.2564   4859.267     -1.040      0.299   -1.46e+04    4478.140
# Mas Vnr Type_0       -1.686e+04   5722.051     -2.947      0.003   -2.81e+04   -5637.841
# Mas Vnr Type_BrkCmn  -3.209e+04   6722.982     -4.773      0.000   -4.53e+04   -1.89e+04
# Mas Vnr Type_BrkFace -2.001e+04   4171.960     -4.796      0.000   -2.82e+04   -1.18e+04
# Mas Vnr Type_CBlock   7.105e-11   2.02e-11      3.511      0.000    3.14e-11    1.11e-10
# Mas Vnr Type_None    -1.794e+04   4103.614     -4.371      0.000    -2.6e+04   -9887.165
# Mas Vnr Type_Stone   -1.471e+04   4382.650     -3.357      0.001   -2.33e+04   -6118.702
# Exter Qual_Ex        -5714.5761   5822.507     -0.981      0.326   -1.71e+04    5705.007
# Exter Qual_Fa        -2.933e+04   6710.715     -4.371      0.000   -4.25e+04   -1.62e+04
# Exter Qual_Gd        -3.182e+04   5148.882     -6.180      0.000   -4.19e+04   -2.17e+04
# Exter Qual_TA        -3.474e+04   4978.890     -6.977      0.000   -4.45e+04    -2.5e+04
# Exter Cond_Ex        -2.079e+04   9508.178     -2.187      0.029   -3.94e+04   -2143.376
# Exter Cond_Fa        -2.081e+04   6593.634     -3.156      0.002   -3.37e+04   -7878.226
# Exter Cond_Gd        -2.213e+04   6254.638     -3.538      0.000   -3.44e+04   -9864.793
# Exter Cond_Po        -1.729e+04   1.84e+04     -0.941      0.347   -5.33e+04    1.87e+04
# Exter Cond_TA        -2.059e+04   6129.263     -3.359      0.001   -3.26e+04   -8564.043
# Foundation_BrkTil    -2.318e+04   4780.184     -4.849      0.000   -3.26e+04   -1.38e+04
# Foundation_CBlock    -2.243e+04   4693.411     -4.780      0.000   -3.16e+04   -1.32e+04
# Foundation_PConc     -1.856e+04   4937.688     -3.759      0.000   -2.82e+04   -8874.163
# Foundation_Slab      -2.058e+04   7714.121     -2.667      0.008   -3.57e+04   -5445.922
# Foundation_Stone     -1.296e+04   1.06e+04     -1.223      0.221   -3.37e+04    7815.757
# Foundation_Wood      -3898.2008   1.44e+04     -0.271      0.786   -3.21e+04    2.43e+04
# Bsmt Qual_0          -6106.1336   8513.641     -0.717      0.473   -2.28e+04    1.06e+04
# Bsmt Qual_Ex         -8779.7260   6934.829     -1.266      0.206   -2.24e+04    4821.435
# Bsmt Qual_Fa         -1.934e+04   6578.964     -2.939      0.003   -3.22e+04   -6432.949
# Bsmt Qual_Gd         -2.498e+04   6567.567     -3.804      0.000   -3.79e+04   -1.21e+04
# Bsmt Qual_Po         -2.055e+04   2.17e+04     -0.946      0.344   -6.31e+04     2.2e+04
# Bsmt Qual_TA         -2.185e+04   6287.480     -3.475      0.001   -3.42e+04   -9515.716
# Bsmt Cond_0          -6106.1336   8513.641     -0.717      0.473   -2.28e+04    1.06e+04
# Bsmt Cond_Ex         -2.926e+04   1.21e+04     -2.418      0.016    -5.3e+04   -5529.417
# Bsmt Cond_Fa          -2.04e+04   5505.422     -3.705      0.000   -3.12e+04   -9599.318
# Bsmt Cond_Gd         -1.842e+04   5390.034     -3.417      0.001    -2.9e+04   -7848.625
# Bsmt Cond_Po         -8356.6878   1.11e+04     -0.750      0.454   -3.02e+04    1.35e+04
# Bsmt Cond_TA         -1.906e+04   5004.268     -3.809      0.000   -2.89e+04   -9246.494
# Bsmt Exposure_0      -2.817e+04   1.12e+04     -2.522      0.012   -5.01e+04   -6266.307
# Bsmt Exposure_Av     -1.849e+04   4669.687     -3.959      0.000   -2.76e+04   -9329.888
# Bsmt Exposure_Gd     -7089.7645   4850.116     -1.462      0.144   -1.66e+04    2422.685
# Bsmt Exposure_Mn      -2.47e+04   4719.342     -5.233      0.000    -3.4e+04   -1.54e+04
# Bsmt Exposure_No     -2.316e+04   4570.617     -5.067      0.000   -3.21e+04   -1.42e+04
# BsmtFin Type 1_0     -6106.1336   8513.641     -0.717      0.473   -2.28e+04    1.06e+04
# BsmtFin Type 1_ALQ   -1.503e+04   3366.171     -4.464      0.000   -2.16e+04   -8424.785
# BsmtFin Type 1_BLQ   -1.621e+04   3358.389     -4.826      0.000   -2.28e+04   -9619.911
# BsmtFin Type 1_GLQ   -1.245e+04   3411.149     -3.649      0.000   -1.91e+04   -5755.519
# BsmtFin Type 1_LwQ   -1.969e+04   3646.438     -5.401      0.000   -2.68e+04   -1.25e+04
# BsmtFin Type 1_Rec   -1.728e+04   3370.419     -5.126      0.000   -2.39e+04   -1.07e+04
# BsmtFin Type 1_Unf   -1.485e+04   3265.595     -4.547      0.000   -2.13e+04   -8445.173
# BsmtFin Type 2_0      -3.21e+04      2e+04     -1.607      0.108   -7.13e+04    7075.157
# BsmtFin Type 2_ALQ   -9924.9183   5678.476     -1.748      0.081   -2.11e+04    1212.179
# BsmtFin Type 2_BLQ    -1.58e+04   5181.692     -3.049      0.002    -2.6e+04   -5636.572
# BsmtFin Type 2_GLQ    1657.7870   6628.585      0.250      0.803   -1.13e+04    1.47e+04
# BsmtFin Type 2_LwQ   -1.794e+04   5129.097     -3.498      0.000    -2.8e+04   -7880.562
# BsmtFin Type 2_Rec    -1.62e+04   4964.628     -3.264      0.001   -2.59e+04   -6466.636
# BsmtFin Type 2_Unf    -1.13e+04   4883.476     -2.314      0.021   -2.09e+04   -1720.182
# Heating_Floor        -1.189e-11   5.35e-12     -2.220      0.027   -2.24e-11   -1.39e-12
# Heating_GasA         -9956.2313   6458.583     -1.542      0.123   -2.26e+04    2710.876
# Heating_GasW          -1.22e+04   7377.687     -1.654      0.098   -2.67e+04    2264.926
# Heating_Grav         -3.157e+04   1.06e+04     -2.984      0.003   -5.23e+04   -1.08e+04
# Heating_OthW          -4.29e+04   1.46e+04     -2.944      0.003   -7.15e+04   -1.43e+04
# Heating_Wall         -4972.3507   1.12e+04     -0.444      0.657   -2.69e+04     1.7e+04
# Heating QC_Ex        -1.561e+04   5240.874     -2.978      0.003   -2.59e+04   -5327.099
# Heating QC_Fa        -1.562e+04   5516.680     -2.832      0.005   -2.64e+04   -4802.737
# Heating QC_Gd        -1.724e+04   5220.036     -3.303      0.001   -2.75e+04   -7006.257
# Heating QC_Po        -3.361e+04   1.42e+04     -2.373      0.018   -6.14e+04   -5834.939
# Heating QC_TA        -1.952e+04   5129.018     -3.806      0.000   -2.96e+04   -9463.452
# Central Air_N        -4.913e+04   9351.175     -5.254      0.000   -6.75e+04   -3.08e+04
# Central Air_Y        -5.248e+04   9501.531     -5.523      0.000   -7.11e+04   -3.38e+04
# Electrical_0                  0          0        nan        nan           0           0
# Electrical_FuseA     -2.241e+04   8302.990     -2.699      0.007   -3.87e+04   -6121.602
# Electrical_FuseF     -2.196e+04   8912.832     -2.464      0.014   -3.94e+04   -4481.395
# Electrical_FuseP     -2.149e+04   1.12e+04     -1.915      0.056   -4.35e+04     523.481
# Electrical_Mix       -1.273e+04   2.94e+04     -0.432      0.666   -7.05e+04     4.5e+04
# Electrical_SBrkr     -2.302e+04   8417.278     -2.735      0.006   -3.95e+04   -6510.460
# Kitchen Qual_Ex      -8466.3985   5467.265     -1.549      0.122   -1.92e+04    2256.455
# Kitchen Qual_Fa      -3.215e+04   5321.201     -6.041      0.000   -4.26e+04   -2.17e+04
# Kitchen Qual_Gd       -2.98e+04   5077.056     -5.870      0.000   -3.98e+04   -1.98e+04
# Kitchen Qual_Po               0          0        nan        nan           0           0
# Kitchen Qual_TA      -3.119e+04   4792.974     -6.508      0.000   -4.06e+04   -2.18e+04
# Functional_Maj1      -2.159e+04   7914.781     -2.728      0.006   -3.71e+04   -6065.866
# Functional_Maj2      -3774.5591   1.01e+04     -0.375      0.707   -2.35e+04     1.6e+04
# Functional_Min1      -2092.2981   5784.601     -0.362      0.718   -1.34e+04    9252.941
# Functional_Min2      -3517.0510   5637.748     -0.624      0.533   -1.46e+04    7540.166
# Functional_Mod        -1.06e+04   5991.078     -1.769      0.077   -2.24e+04    1149.495
# Functional_Sal       -2.493e+04   2.04e+04     -1.222      0.222   -6.49e+04    1.51e+04
# Functional_Sev       -3.869e+04   1.59e+04     -2.436      0.015   -6.98e+04   -7545.330
# Functional_Typ        3590.9695   4778.911      0.751      0.452   -5781.826     1.3e+04
# Garage Type_0        -1.391e+04   2.02e+04     -0.687      0.492   -5.36e+04    2.58e+04
# Garage Type_2Types   -2.393e+04   6522.583     -3.668      0.000   -3.67e+04   -1.11e+04
# Garage Type_Attchd   -1.314e+04   4728.526     -2.779      0.006   -2.24e+04   -3865.860
# Garage Type_Basment  -1.388e+04   6270.338     -2.214      0.027   -2.62e+04   -1583.970
# Garage Type_BuiltIn   -1.05e+04   5287.567     -1.986      0.047   -2.09e+04    -132.445
# Garage Type_CarPort  -1.367e+04   7780.588     -1.757      0.079   -2.89e+04    1587.741
# Garage Type_Detchd   -1.258e+04   4706.142     -2.673      0.008   -2.18e+04   -3347.792
# Garage Finish_0       -1.66e+04   2.38e+04     -0.696      0.486   -6.34e+04    3.02e+04
# Garage Finish_Fin     -2.77e+04   1.05e+04     -2.644      0.008   -4.82e+04   -7152.718
# Garage Finish_RFn    -3.007e+04   1.04e+04     -2.889      0.004   -5.05e+04   -9653.643
# Garage Finish_Unf    -2.724e+04   1.04e+04     -2.628      0.009   -4.76e+04   -6908.509
# Garage Qual_0         -1.66e+04   2.38e+04     -0.696      0.486   -6.34e+04    3.02e+04
# Garage Qual_Ex         9.48e+04   2.48e+04      3.822      0.000    4.62e+04    1.43e+05
# Garage Qual_Fa       -4.319e+04   9895.485     -4.365      0.000   -6.26e+04   -2.38e+04
# Garage Qual_Gd       -1.904e+04   1.14e+04     -1.675      0.094   -4.13e+04    3250.676
# Garage Qual_Po       -7.452e+04   2.18e+04     -3.421      0.001   -1.17e+05   -3.18e+04
# Garage Qual_TA       -4.306e+04   1.01e+04     -4.284      0.000   -6.28e+04   -2.33e+04
# Garage Cond_0         -1.66e+04   2.38e+04     -0.696      0.486   -6.34e+04    3.02e+04
# Garage Cond_Ex       -1.168e+05   2.77e+04     -4.220      0.000   -1.71e+05   -6.25e+04
# Garage Cond_Fa        6375.8770   9777.943      0.652      0.514   -1.28e+04    2.56e+04
# Garage Cond_Gd        4098.4357   1.11e+04      0.369      0.712   -1.77e+04    2.59e+04
# Garage Cond_Po        1.284e+04   1.24e+04      1.032      0.302   -1.16e+04    3.72e+04
# Garage Cond_TA        8485.3058   9578.334      0.886      0.376   -1.03e+04    2.73e+04
# Paved Drive_N        -3.521e+04   6468.319     -5.443      0.000   -4.79e+04   -2.25e+04
# Paved Drive_P        -3.613e+04   6605.543     -5.470      0.000   -4.91e+04   -2.32e+04
# Paved Drive_Y        -3.026e+04   6674.714     -4.534      0.000   -4.34e+04   -1.72e+04
# Sale Type_COD        -2.367e+04   4222.745     -5.606      0.000    -3.2e+04   -1.54e+04
# Sale Type_CWD        -7092.1991   7270.717     -0.975      0.329   -2.14e+04    7167.732
# Sale Type_Con         1.208e+04   1.07e+04      1.130      0.259   -8882.038     3.3e+04
# Sale Type_ConLD      -1.203e+04   6340.466     -1.897      0.058   -2.45e+04     405.401
# Sale Type_ConLI      -1.886e+04   8371.160     -2.253      0.024   -3.53e+04   -2444.365
# Sale Type_ConLw      -2.014e+04   9674.838     -2.082      0.037   -3.91e+04   -1169.764
# Sale Type_New        -8261.0300   4025.201     -2.052      0.040   -1.62e+04    -366.473
# Sale Type_Oth        -4822.9482   1.06e+04     -0.454      0.650   -2.57e+04     1.6e+04
# Sale Type_VWD                 0          0        nan        nan           0           0
# Sale Type_WD          -1.88e+04   3371.177     -5.575      0.000   -2.54e+04   -1.22e+04
# ==============================================================================
# Omnibus:                      502.460   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29082.985
# Skew:                           0.107   Prob(JB):                         0.00
# Kurtosis:                      21.446   Cond. No.                     3.12e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.14e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
